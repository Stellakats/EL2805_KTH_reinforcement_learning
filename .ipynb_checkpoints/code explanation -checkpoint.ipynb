# %% [markdown]
# ## LAB2: Question b
# *Familiarize yourself with the code. Provide a brief description outlining the steps taken in
# main as well as the behavior of each function.*

# %%
import sys
import gym
import pylab
import random
import numpy as np
from collections import deque
from keras.layers import Dense
from keras.optimizers import Adam
from keras.models import Sequential
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

EPISODES = 1000 #Maximum number of episodes

#DQN Agent for the Cartpole
#Q function approximation with NN, experience replay, and target network
class DQNAgent:
    #Constructor for the agent (invoked when DQN is first called in main)
    def __init__(self, state_size, action_size):
        self.check_solve = False	#If True, stop if you satisfy solution confition
        self.render = True        #If you want to see Cartpole learning, then change to True

        #Get size of state and action
        self.state_size = state_size
        self.action_size = action_size

       # Modify here

        #Set hyper parameters for the DQN. Do not adjust those labeled as Fixed.
        self.discount_factor = 0.95
        self.learning_rate = 0.005
        self.epsilon = 0.02 #Fixed
        self.batch_size = 32 #Fixed
        self.memory_size = 1000
        self.train_start = 1000 #Fixed
        self.target_update_frequency = 1

        #Number of test states for Q value plots
        self.test_state_no = 10000

        #Create memory buffer using deque
        self.memory = deque(maxlen=self.memory_size)

        #Create main network and target network (using build_model defined below)
        self.model = self.build_model()
        self.target_model = self.build_model()

        #Initialize target network
        self.update_target_model()

    #Approximate Q function using Neural Network
    #State is the input and the Q Values are the output.
###############################################################################
###############################################################################
        #Edit the Neural Network model here
        #Tip: Consult https://keras.io/getting-started/sequential-model-guide/
    def build_model(self):
        model = Sequential()
        model.add(Dense(16, input_dim=self.state_size, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(self.action_size, activation='linear',
                        kernel_initializer='he_uniform'))
        model.summary()
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        return model
###############################################################################
###############################################################################

    #After some time interval update the target model to be same with model
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    #Get action from model using epsilon-greedy policy
    def get_action(self, state):
###############################################################################
###############################################################################
        #Insert your e-greedy policy code here
        #Tip 1: Use the random package to generate a random action.
        #Tip 2: Use keras.model.predict() to compute Q-values from the state.
        random_int = np.random.binomial(1, (1 - self.epsilon))
        if random_int == 1:
            qs = self.model.predict(state) #model is going to give me two q values, one for each action that can be taken from state.
            action = np.argmax(qs)
        elif random_int == 0:
            action = random.randrange(self.action_size)
        return action
###############################################################################
###############################################################################
    #Save sample <s,a,r,s'> to the replay memory
    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done)) #Add sample to the end of the list

    #Sample <s,a,r,s'> from replay memory
    def train_model(self):
        if len(self.memory) < self.train_start: #Do not train if not enough memory
            return
        batch_size = min(self.batch_size, len(self.memory)) #Train on at most as many samples as you have in memory
        mini_batch = random.sample(self.memory, batch_size) #Uniformly sample the memory buffer
        #Preallocate network and target network input matrices.
        update_input = np.zeros((batch_size, self.state_size)) #batch_size by state_size two-dimensional array (not matrix!)
        update_target = np.zeros((batch_size, self.state_size)) #Same as above, but used for the target network
        action, reward, done = [], [], [] #Empty arrays that will grow dynamically

        for i in range(self.batch_size):
            update_input[i] = mini_batch[i][0] #Allocate s(i) to the network input array from iteration i in the batch
            action.append(mini_batch[i][1]) #Store a(i)
            reward.append(mini_batch[i][2]) #Store r(i)
            update_target[i] = mini_batch[i][3] #Allocate s'(i) for the target network array from iteration i in the batch
            done.append(mini_batch[i][4])  #Store done(i)

        target = self.model.predict(update_input) #Generate target values for training the inner loop network using the network model
        target_val = self.target_model.predict(update_target) #Generate the target values for training the outer loop target network

        #Q Learning: get maximum Q value at s' from target network
###############################################################################
###############################################################################
        #Insert your Q-learning code here
        #Tip 1: Observe that the Q-values are stored in the variable target
        #Tip 2: What is the Q-value of the action taken at the last state of the episode?
        for i in range(self.batch_size): #For every batch
            if done[i]:
                target[i][action[i]] = reward[i]
            else:
                target[i][action[i]] = reward[i] + self.discount_factor * (np.max(target_val[i]))
###############################################################################
###############################################################################

        #Train the inner loop network
        self.model.fit(update_input, target, batch_size=self.batch_size,
                       epochs=1, verbose=0)
        return


    #Plots the score per episode as well as the maximum q value per episode, averaged over precollected states.
    def plot_data(self, episodes, scores, max_q_mean):
        pylab.figure(0)
        pylab.plot(episodes, max_q_mean, 'b')
        pylab.xlabel("Episodes")
        pylab.ylabel("Average Q Value")
        pylab.savefig("qvalues.png")

        pylab.figure(1)
        pylab.plot(episodes, scores, 'b')
        pylab.xlabel("Episodes")
        pylab.ylabel("Score")
        pylab.savefig("scores.png")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# First we create the Cartpole-v0 environment object from gym library:

# %%
env = gym.make('CartPole-v0')

# %% [markdown]
# We get the state and action sizes out of this environment:

# %%
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
print(state_size)
print(action_size)
# Out:
# 4
# 2

# %% [markdown]
# next we create a DQNSolver agent, with an observation space (possible state values) and an action space (possible actions that can be performed), see below:

# %%
agent = DQNAgent(state_size, action_size)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 16)                80
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 114
# Trainable params: 114
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 16)                80
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 114
# Trainable params: 114
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# we now pick 10.000 states. Note that these are sequential, but generated by taking random actions. Esentially we want to end up having an average of maximum q value correpsponding to each episode and that is what will be ploted in the end.
#
# We will be using our trained model for this particular line "tmp = agent.model.predict(test_states)". This way, we will be able to check whether our model improves over episodes. This happens because the model weights are updates in the inner loop during training (the one loop that iterates over time steps) to reduce the loss between the target and the q values predicted by the current model.

# %%
test_states = np.zeros((agent.test_state_no, state_size))

# %% [markdown]
# and we fill the matrix up, with states chosen randomly:

# %%
done = True
for i in range(agent.test_state_no):
    if done:
        done = False
        state = env.reset()
        state = np.reshape(state, [1, state_size])
        test_states[i] = state
    else:
        action = random.randrange(action_size)  # choose a random action out of the two
        next_state, reward, done, info = env.step(action)  #
        next_state = np.reshape(next_state, [1, state_size])
        test_states[i] = state
        state = next_state

# %% [markdown]
# we initialize max_q and max_q_mean:

# %%
max_q = np.zeros((EPISODES, agent.test_state_no))
max_q_mean = np.zeros((EPISODES,1))

# %% [markdown]
# we now initialize the two lists that we will be using for our plots:

# %%
scores = []
episodes = []

# %% [markdown]
# The next lines of code are going to fill these lists up.
#
# The steps will be described with comments inside the code snipet:

# %%
for e in range(EPISODES):
    done = False
    score = 0
    state = env.reset() #Initialize/reset the environment
    state = np.reshape(state, [1, state_size]) #Reshape state so that to a 1 by state_size two-dimensional array ie. [x_1,x_2] to [[x_1,x_2]]
    # SO HERE WE USED OUR TRAINED MODEL TO PREDICT THE Q VALUES (this is the tmp). 
    # RECALL THAT WE ARE DOING THIS FOR THE SET OF RANDOM STATES CREATED BEFORE.
    # SO FOR EACH OF THE 10.000 STATES WE TAKE THE MAXIMUM OF THE TWO Q VALUES IN THE tmp MATRIX = THAT WILL GIVE US max_q (SHAPE IS (episodes,10.000)
    # AND THEN FOR EACH EPISODE WE TAKE THE MEAN OF THE 10.000 VALUES = THAT WILL GIVE US max_q_mean (shape is (episodes,1))
    # AND THIS IS WHAT WE WILL EVENTUALLY PLOT.
    #Compute Q values for plotting
    tmp = agent.model.predict(test_states) # 10.000 x 2 
    max_q[e][:] = np.max(tmp, axis=1) #  episodes x 10.000
    max_q_mean[e] = np.mean(max_q[e][:]) #  episodes x 1 

    while not done:
        if agent.render:
            env.render() #Show cartpole animation

        #Get action for the current state and go one step in environment
        action = agent.get_action(state) # EXPLORE OR EXPLOIT 
        #EXECUTE SELECTED ACTION IN THE GYM EMULATOR AND OBSERVE REWARD AND NEXT STATE. ALSO WHETHER WE ARE DONE OR NOT. (FAILURE OR  NOT)
        next_state, reward, done, info = env.step(action) 
        next_state = np.reshape(next_state, [1, state_size]) #Reshape next_state similarly to state

        #Save sample <s, a, r, s'> to the replay memory
        agent.append_sample(state, action, reward, next_state, done) #STORE EXPERIENCE IN THE REPLAY MEMORY
        #Training step
        agent.train_model() # HERE WE USE OUR TWO NETWORKS.
        score += reward #Store episodic reward
        state = next_state #Propagate state

        if done:
            #At the end of very episode, update the target network
            if e % agent.target_update_frequency == 0:
                agent.update_target_model()
            #Plot the play time for every episode
            scores.append(score)
            episodes.append(e)

            print("episode:", e, "  score:", score," q_value:", max_q_mean[e],"  memory length:",
                  len(agent.memory))

            # if the mean of scores of last 100 episodes is bigger than 195
            # stop training
            if agent.check_solve:
                if np.mean(scores[-min(100, len(scores)):]) >= 195:
                    print("solved after", e-100, "episodes")
                    agent.plot_data(episodes,scores,max_q_mean[:e+1])
                    sys.exit()
agent.plot_data(episodes, scores, max_q_mean)
# Out:
# ('episode:', 0, '  score:', 8.0, ' q_value:', array([0.23248849]), '  memory length:', 9)
# ('episode:', 1, '  score:', 9.0, ' q_value:', array([0.23248849]), '  memory length:', 18)
# ('episode:', 2, '  score:', 8.0, ' q_value:', array([0.23248849]), '  memory length:', 26)
# ('episode:', 3, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 36)
# ('episode:', 4, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 46)
# ('episode:', 5, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 56)
# ('episode:', 6, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 66)
# ('episode:', 7, '  score:', 9.0, ' q_value:', array([0.23248849]), '  memory length:', 75)
# ('episode:', 8, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 85)
# ('episode:', 9, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 95)
# ('episode:', 10, '  score:', 11.0, ' q_value:', array([0.23248849]), '  memory length:', 106)
# ('episode:', 11, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 116)
# ('episode:', 12, '  score:', 11.0, ' q_value:', array([0.23248849]), '  memory length:', 127)
# ('episode:', 13, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 137)
# ('episode:', 14, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 147)
# ('episode:', 15, '  score:', 9.0, ' q_value:', array([0.23248849]), '  memory length:', 156)
# ('episode:', 16, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 166)
# ('episode:', 17, '  score:', 9.0, ' q_value:', array([0.23248849]), '  memory length:', 175)
# ('episode:', 18, '  score:', 8.0, ' q_value:', array([0.23248849]), '  memory length:', 183)
# ('episode:', 19, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 193)
# ('episode:', 20, '  score:', 9.0, ' q_value:', array([0.23248849]), '  memory length:', 202)
# ('episode:', 21, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 212)
# ('episode:', 22, '  score:', 9.0, ' q_value:', array([0.23248849]), '  memory length:', 221)
# ('episode:', 23, '  score:', 9.0, ' q_value:', array([0.23248849]), '  memory length:', 230)
# ('episode:', 24, '  score:', 8.0, ' q_value:', array([0.23248849]), '  memory length:', 238)
# ('episode:', 25, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 248)
# ('episode:', 26, '  score:', 9.0, ' q_value:', array([0.23248849]), '  memory length:', 257)
# ('episode:', 27, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 267)
# ('episode:', 28, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 277)
# ('episode:', 29, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 287)
# ('episode:', 30, '  score:', 9.0, ' q_value:', array([0.23248849]), '  memory length:', 296)
# ('episode:', 31, '  score:', 12.0, ' q_value:', array([0.23248849]), '  memory length:', 308)
# ('episode:', 32, '  score:', 9.0, ' q_value:', array([0.23248849]), '  memory length:', 317)
# ('episode:', 33, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 327)
# ('episode:', 34, '  score:', 8.0, ' q_value:', array([0.23248849]), '  memory length:', 335)
# ('episode:', 35, '  score:', 8.0, ' q_value:', array([0.23248849]), '  memory length:', 343)
# ('episode:', 36, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 353)
# ('episode:', 37, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 363)
# ('episode:', 38, '  score:', 8.0, ' q_value:', array([0.23248849]), '  memory length:', 371)
# ('episode:', 39, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 381)
# ('episode:', 40, '  score:', 9.0, ' q_value:', array([0.23248849]), '  memory length:', 390)
# ('episode:', 41, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 400)
# ('episode:', 42, '  score:', 9.0, ' q_value:', array([0.23248849]), '  memory length:', 409)
# ('episode:', 43, '  score:', 10.0, ' q_value:', array([0.23248849]), '  memory length:', 419)
# ('episode:', 44, '  score:', 9.0, ' q_value:', array([0.23248849]), '  memory length:',
# ('episode:', 114, '  score:', 10.0, ' q_value:', array([2.6934504]), '  memory length:', 1000)
# ('episode:', 115, '  score:', 10.0, ' q_value:', array([3.01643582]), '  memory length:', 1000)
# ('episode:', 116, '  score:', 9.0, ' q_value:', array([3.44444297]), '  memory length:', 1000)
# ('episode:', 117, '  score:', 9.0, ' q_value:', array([3.77065786]), '  memory length:', 1000)
# ('episode:', 118, '  score:', 11.0, ' q_value:', array([4.14769255]), '  memory length:', 1000)
# ('episode:', 119, '  score:', 19.0, ' q_value:', array([4.72732419]), '  memory length:', 1000)
# ('episode:', 120, '  score:', 9.0, ' q_value:', array([5.46249943]), '  memory length:', 1000)
# ('episode:', 121, '  score:', 16.0, ' q_value:', array([5.95262945]), '  memory length:', 1000)
# ('episode:', 122, '  score:', 15.0, ' q_value:', array([6.59961041]), '  memory length:', 1000)
# ('episode:', 123, '  score:', 10.0, ' q_value:', array([7.37889431]), '  memory length:', 1000)
# ('episode:', 124, '  score:', 11.0, ' q_value:', array([8.0821662]), '  memory length:', 1000)
# ('episode:', 125, '  score:', 16.0, ' q_value:', array([8.48276866]), '  memory length:', 1000)
# ('episode:', 126, '  score:', 15.0, ' q_value:', array([9.4733427]), '  memory length:', 1000)
# ('episode:', 127, '  score:', 13.0, ' q_value:', array([10.25822362]), '  memory length:', 1000)
# ('episode:', 128, '  score:', 20.0, ' q_value:', array([10.65695754]), '  memory length:', 1000)
# ('episode:', 129, '  score:', 54.0, ' q_value:', array([11.35840109]), '  memory length:', 1000)
# ('episode:', 130, '  score:', 44.0, ' q_value:', array([11.78617914]), '  memory length:', 1000)
# ('episode:', 131, '  score:', 21.0, ' q_value:', array([12.26289193]), '  memory length:', 1000)
# ('episode:', 132, '  score:', 15.0, ' q_value:', array([12.94183256]), '  memory length:', 1000)
# ('episode:', 133, '  score:', 14.0, ' q_value:', array([13.32416736]), '  memory length:', 1000)
# ('episode:', 134, '  score:', 18.0, ' q_value:', array([13.44340843]), '  memory length:', 1000)
# ('episode:', 135, '  score:', 17.0, ' q_value:', array([13.98579259]), '  memory length:', 1000)
# ('episode:', 136, '  score:', 12.0, ' q_value:', array([14.71396792]), '  memory length:', 1000)
# ('episode:', 137, '  score:', 21.0, ' q_value:', array([14.99310724]), '  memory length:', 1000)
# ('episode:', 138, '  score:', 13.0, ' q_value:', array([15.22829942]), '  memory length:', 1000)
# ('episode:', 139, '  score:', 28.0, ' q_value:', array([15.65923185]), '  memory length:', 1000)
# ('episode:', 140, '  score:', 16.0, ' q_value:', array([15.82768087]), '  memory length:', 1000)
# ('episode:', 141, '  score:', 23.0, ' q_value:', array([16.16499102]), '  memory length:', 1000)
# ('episode:', 142, '  score:', 15.0, ' q_value:', array([15.85234431]), '  memory length:', 1000)
# ('episode:', 143, '  score:', 13.0, ' q_value:', array([16.28502506]), '  memory length:', 1000)
# ('episode:', 144, '  score:', 10.0, ' q_value:', array([16.65616234]), '  memory length:', 1000)
# ('episode:', 145, '  score:', 12.0, ' q_value:', array([16.51184023]), '  memory length:', 1000)
# ('episode:', 840, '  score:', 200.0, ' q_value:', array([19.88278958]), '  memory length:', 1000)
# ('episode:', 841, '  score:', 200.0, ' q_value:', array([19.67019178]), '  memory length:', 1000)
# ('episode:', 842, '  score:', 200.0, ' q_value:', array([19.42905312]), '  memory length:', 1000)
# ('episode:', 843, '  score:', 200.0, ' q_value:', array([19.08859991]), '  memory length:', 1000)
# ('episode:', 844, '  score:', 200.0, ' q_value:', array([18.85221134]), '  memory length:', 1000)
# ('episode:', 845, '  score:', 200.0, ' q_value:', array([19.1518732]), '  memory length:', 1000)
# ('episode:', 846, '  score:', 171.0, ' q_value:', array([19.18406708]), '  memory length:', 1000)
# ('episode:', 847, '  score:', 188.0, ' q_value:', array([19.20044793]), '  memory length:', 1000)
# ('episode:', 848, '  score:', 200.0, ' q_value:', array([19.10327948]), '  memory length:', 1000)
# ('episode:', 849, '  score:', 200.0, ' q_value:', array([19.28889666]), '  memory length:', 1000)
# ('episode:', 850, '  score:', 193.0, ' q_value:', array([19.29294631]), '  memory length:', 1000)
# ('episode:', 851, '  score:', 196.0, ' q_value:', array([19.29481071]), '  memory length:', 1000)
# ('episode:', 852, '  score:', 200.0, ' q_value:', array([19.34290291]), '  memory length:', 1000)
# ('episode:', 853, '  score:', 200.0, ' q_value:', array([19.35636607]), '  memory length:', 1000)
# ('episode:', 854, '  score:', 200.0, ' q_value:', array([19.23421871]), '  memory length:', 1000)
# ('episode:', 855, '  score:', 200.0, ' q_value:', array([19.36136161]), '  memory length:', 1000)
# ('episode:', 856, '  score:', 200.0, ' q_value:', array([19.42537248]), '  memory length:', 1000)
# ('episode:', 857, '  score:', 200.0, ' q_value:', array([19.48632846]), '  memory length:', 1000)
# ('episode:', 858, '  score:', 200.0, ' q_value:', array([19.67387473]), '  memory length:', 1000)
# ('episode:', 859, '  score:', 200.0, ' q_value:', array([19.54512802]), '  memory length:', 1000)
# ('episode:', 860, '  score:', 200.0, ' q_value:', array([19.3759272]), '  memory length:', 1000)
# ('episode:', 861, '  score:', 200.0, ' q_value:', array([19.26056328]), '  memory length:', 1000)
# ('episode:', 862, '  score:', 200.0, ' q_value:', array([19.49993117]), '  memory length:', 1000)
# ('episode:', 863, '  score:', 200.0, ' q_value:', array([19.40676968]), '  memory length:', 1000)
# ('episode:', 864, '  score:', 200.0, ' q_value:', array([19.29904959]), '  memory length:', 1000)
# ('episode:', 865, '  score:', 200.0, ' q_value:', array([19.12856767]), '  memory length:', 1000)
# ('episode:', 866, '  score:', 200.0, ' q_value:', array([19.14797982]), '  memory length:', 1000)
# ('episode:', 867, '  score:', 200.0, ' q_value:', array([19.23034617]), '  memory length:', 1000)
# ('episode:', 868, '  score:', 200.0, ' q_value:', array([19.10683501]), '  memory length:', 1000)
# ('episode:', 869, '  score:', 200.0, ' q_value:', array([19.10537413]), '  memory length:', 1000)
# ('episode:', 870, '  score:', 200.0, ' q_value:', array([19.23356154]), '  memory length:', 1000)
# ('episode:', 871, '  score:', 200.0, ' q_value:', array([19.07018756]), '  memory length:', 1000)
# ('episode:', 872, '  score:', 200.0, ' q_value:', array([19.2861163]), '  memory length:', 1000)
# ('episode:', 873, '  score:', 200.0, ' q_value:', array([19.21454895]), '  memory length:', 1000)
# ('episode:', 874, '  score:', 200.0, ' q_value:', array([19.27338992]), '  memory length:', 1000)
# ('episode:', 875, '  score:', 200.0, ' q_value:', array([19.4704201]), '  memory length:', 1000)
# ('episode:', 876, '  score:', 200.0, ' q_value:', array([19.57627024]), '  memory length:', 1000)
# ('episode:', 877, '  score:', 186.0, ' q_value:', array([19.67525113]), '  memory length:', 1000)
# ('episode:', 878, '  score:', 200.0, ' q_value:', array([19.71198576]), '  memory length:', 1000)
# ('episode:', 879, '  score:', 200.0, ' q_value:', array([19.71089671]), '  memory length:', 1000)
# ('episode:', 880, '  score:', 200.0, ' q_value:', array([19.60957068]), '  memory length:', 1000)
# ('episode:', 881, '  score:', 200.0, ' q_value:', array([19.57433519]), '  memory length:', 1000)
# ('episode:', 882, '  score:', 158.0, ' q_value:', array([19.32559808]), '  memory length:', 1000)
# ('episode:', 883, '  score:', 200.0, ' q_value:', array([19.27977604]), '  memory length:', 1000)
# ('episode:', 884, '  score:', 200.0, ' q_value:', array([19.30731358]), '  memory length:', 1000)
# ('episode:', 885, '  score:', 200.0, ' q_value:', array([19.35892724]), '  memory length:', 1000)
# ('episode:', 886, '  score:', 200.0, ' q_value:', array([19.29073826]), '  memory length:', 1000)
# ('episode:', 887, '  score:', 200.0, ' q_value:', array([19.35861217]), '  memory length:', 1000)
# ('episode:', 888, '  score:', 200.0, ' q_value:', array([19.32914713]), '  memory length:', 1000)
# ('episode:', 889, '  score:', 200.0, ' q_value:', array([19.43697151]), '  memory length:', 1000)
# ('episode:', 890, '  score:', 200.0, ' q_value:', array([19.42508088]), '  memory length:', 1000)
# ('episode:', 891, '  score:', 200.0, ' q_value:', array([19.46769249]), '  memory length:', 1000)
# ('episode:', 892, '  score:', 200.0, ' q_value:', array([19.30097351]), '  memory length:', 1000)
# ('episode:', 893, '  score:', 200.0, ' q_value:', array([19.45917209]), '  memory length:', 1000)
# ('episode:', 894, '  score:', 200.0, ' q_value:', array([19.47425059]), '  memory length:', 1000)
# ('episode:', 895, '  score:', 200.0, ' q_value:', array([19.19350313]), '  memory length:', 1000)
# ('episode:', 896, '  score:', 200.0, ' q_value:', array([19.18894658]), '  memory length:', 1000)
# ('episode:', 897, '  score:', 200.0, ' q_value:', array([19.10247678]), '  memory length:', 1000)
# ('episode:', 898, '  score:', 200.0, ' q_value:', array([19.04296571]), '  memory length:', 1000)
# ('episode:', 899, '  score:', 200.0, ' q_value:', array([19.15440312]), '  memory length:', 1000)
# ('episode:', 900, '  score:', 130.0, ' q_value:', array([19.22934442]), '  memory length:', 1000)
# ('episode:', 901, '  score:', 181.0, ' q_value:', array([19.26086073]), '  memory length:', 1000)
# ('episode:', 902, '  score:', 171.0, ' q_value:', array([19.23780169]), '  memory length:', 1000)
# ('episode:', 903, '  score:', 200.0, ' q_value:', array([19.22779694]), '  memory length:', 1000)
# ('episode:', 904, '  score:', 200.0, ' q_value:', array([19.1978995]), '  memory length:', 1000)
# ('episode:', 905, '  score:', 200.0, ' q_value:', array([19.16257814]), '  memory length:', 1000)
# ('episode:', 906, '  score:', 200.0, ' q_value:', array([19.14280128]), '  memory length:', 1000)
# ('episode:', 907, '  score:', 200.0, ' q_value:', array([19.085592]), '  memory length:', 1000)
# ('episode:', 908, '  score:', 200.0, ' q_value:', array([19.20307121]), '  memory length:', 1000)
# ('episode:', 909, '  score:', 200.0, ' q_value:', array([19.28455297]), '  memory length:', 1000)
# ('episode:', 910, '  score:', 74.0, ' q_value:', array([19.10172087]), '  memory length:', 1000)
# ('episode:', 911, '  score:', 56.0, ' q_value:', array([19.02899205]), '  memory length:', 1000)
# ('episode:', 912, '  score:', 64.0, ' q_value:', array([19.03428547]), '  memory length:', 1000)
# ('episode:', 913, '  score:', 90.0, ' q_value:', array([19.06818909]), '  memory length:', 1000)
# ('episode:', 914, '  score:', 18.0, ' q_value:', array([18.98117072]), '  memory length:', 1000)
# ('episode:', 915, '  score:', 200.0, ' q_value:', array([18.86236923]), '  memory length:', 1000)
# ('episode:', 916, '  score:', 183.0, ' q_value:', array([18.60837638]), '  memory length:', 1000)
# ('episode:', 917, '  score:', 145.0, ' q_value:', array([18.75257773]), '  memory length:', 1000)
# ('episode:', 918, '  score:', 177.0, ' q_value:', array([18.95144915]), '  memory length:', 1000)
# ('episode:', 919, '  score:', 156.0, ' q_value:', array([19.10294553]), '  memory length:', 1000)
# ('episode:', 920, '  score:', 156.0, ' q_value:', array([19.28985394]), '  memory length:', 1000)
# ('episode:', 921, '  score:', 147.0, ' q_value:', array([19.51955489]), '  memory length:', 1000)
# ('episode:', 922, '  score:', 142.0, ' q_value:', array([19.71032747]), '  memory length:', 1000)
# ('episode:', 923, '  score:', 150.0, ' q_value:', array([19.71876617]), '  memory length:', 1000)
# ('episode:', 924, '  score:', 151.0, ' q_value:', array([19.56170631]), '  memory length:', 1000)
# ('episode:', 925, '  score:', 159.0, ' q_value:', array([19.55061708]), '  memory length:', 1000)
# ('episode:', 926, '  score:', 148.0, ' q_value:', array([19.40715956]), '  memory length:', 1000)
# ('episode:', 927, '  score:', 160.0, ' q_value:', array([19.3288171]), '  memory length:', 1000)
# ('episode:', 928, '  score:', 155.0, ' q_value:', array([19.24186133]), '  memory length:', 1000)
# ('episode:', 929, '  score:', 148.0, ' q_value:', array([19.11920833]), '  memory length:', 1000)
# ('episode:', 930, '  score:', 165.0, ' q_value:', array([19.08762902]), '  memory length:', 1000)
# ('episode:', 931, '  score:', 165.0, ' q_value:', array([19.0980586]), '  memory length:', 1000)
# ('episode:', 932, '  score:', 183.0, ' q_value:', array([19.01941243]), '  memory length:', 1000)
# ('episode:', 933, '  score:', 192.0, ' q_value:', array([19.03608704]), '  memory length:', 1000)
# ('episode:', 934, '  score:', 179.0, ' q_value:', array([18.96206518]), '  memory length:', 1000)
# ('episode:', 935, '  score:', 191.0, ' q_value:', array([19.0076717]), '  memory length:', 1000)
# ('episode:', 936, '  score:', 179.0, ' q_value:', array([18.97394327]), '  memory length:', 1000)
# ('episode:', 937, '  score:', 172.0, ' q_value:', array([19.06730177]), '  memory length:', 1000)
# ('episode:', 938, '  score:', 173.0, ' q_value:', array([19.09008724]), '  memory length:', 1000)
# ('episode:', 939, '  score:', 177.0, ' q_value:', array([19.20420537]), '  memory length:', 1000)
# ('episode:', 940, '  score:', 200.0, ' q_value:', array([19.21380281]), '  memory length:', 1000)
# ('episode:', 941, '  score:', 200.0, ' q_value:', array([19.29509793]), '  memory length:', 1000)
# ('episode:', 942, '  score:', 190.0, ' q_value:', array([19.37245699]), '  memory length:', 1000)
# ('episode:', 943, '  score:', 21.0, ' q_value:', array([19.38383091]), '  memory length:', 1000)
# ('episode:', 944, '  score:', 19.0, ' q_value:', array([19.43797906]), '  memory length:', 1000)
# ('episode:', 945, '  score:', 25.0, ' q_value:', array([19.58503287]), '  memory length:', 1000)
# ('episode:', 946, '  score:', 19.0, ' q_value:', array([19.47625268]), '  memory length:', 1000)
# ('episode:', 947, '  score:', 28.0, ' q_value:', array([19.23692396]), '  memory length:', 1000)
# ('episode:', 948, '  score:', 200.0, ' q_value:', array([18.9136944]), '  memory length:', 1000)
# ('episode:', 949, '  score:', 200.0, ' q_value:', array([19.48609323]), '  memory length:', 1000)
# ('episode:', 950, '  score:', 200.0, ' q_value:', array([19.55595651]), '  memory length:', 1000)
# ('episode:', 951, '  score:', 200.0, ' q_value:', array([19.91994744]), '  memory length:', 1000)
# ('episode:', 952, '  score:', 200.0, ' q_value:', array([20.08094537]), '  memory length:', 1000)
# ('episode:', 953, '  score:', 200.0, ' q_value:', array([20.00300717]), '  memory length:', 1000)
# ('episode:', 954, '  score:', 200.0, ' q_value:', array([20.34374358]), '  memory length:', 1000)
# ('episode:', 955, '  score:', 200.0, ' q_value:', array([20.48049059]), '  memory length:', 1000)
# ('episode:', 956, '  score:', 200.0, ' q_value:', array([20.48711225]), '  memory length:', 1000)
# ('episode:', 957, '  score:', 200.0, ' q_value:', array([20.30405786]), '  memory length:', 1000)
# ('episode:', 958, '  score:', 200.0, ' q_value:', array([20.11355542]), '  memory length:', 1000)
# ('episode:', 959, '  score:', 200.0, ' q_value:', array([19.72112096]), '  memory length:', 1000)
# ('episode:', 960, '  score:', 200.0, ' q_value:', array([19.81972344]), '  memory length:', 1000)
# ('episode:', 961, '  score:', 200.0, ' q_value:', array([19.78472567]), '  memory length:', 1000)
# ('episode:', 962, '  score:', 200.0, ' q_value:', array([19.83808715]), '  memory length:', 1000)
# ('episode:', 963, '  score:', 178.0, ' q_value:', array([19.8007923]), '  memory length:', 1000)
# ('episode:', 964, '  score:', 135.0, ' q_value:', array([19.93440372]), '  memory length:', 1000)
# ('episode:', 965, '  score:', 200.0, ' q_value:', array([19.88144453]), '  memory length:', 1000)
# ('episode:', 966, '  score:', 200.0, ' q_value:', array([19.72275049]), '  memory length:', 1000)
# ('episode:', 967, '  score:', 200.0, ' q_value:', array([19.51758233]), '  memory length:', 1000)
# ('episode:', 968, '  score:', 200.0, ' q_value:', array([19.35711525]), '  memory length:', 1000)
# ('episode:', 969, '  score:', 200.0, ' q_value:', array([19.24671239]), '  memory length:', 1000)
# ('episode:', 970, '  score:', 200.0, ' q_value:', array([19.18973649]), '  memory length:', 1000)
# ('episode:', 971, '  score:', 191.0, ' q_value:', array([18.90573731]), '  memory length:', 1000)
# ('episode:', 972, '  score:', 200.0, ' q_value:', array([18.70563953]), '  memory length:', 1000)
# ('episode:', 973, '  score:', 145.0, ' q_value:', array([19.14719326]), '  memory length:', 1000)
# ('episode:', 974, '  score:', 200.0, ' q_value:', array([19.11365613]), '  memory length:', 1000)
# ('episode:', 975, '  score:', 200.0, ' q_value:', array([18.93566677]), '  memory length:', 1000)
# ('episode:', 976, '  score:', 200.0, ' q_value:', array([19.00178243]), '  memory length:', 1000)
# ('episode:', 977, '  score:', 162.0, ' q_value:', array([18.75989224]), '  memory length:', 1000)
# ('episode:', 978, '  score:', 126.0, ' q_value:', array([18.88206293]), '  memory length:', 1000)
# ('episode:', 979, '  score:', 198.0, ' q_value:', array([19.09053097]), '  memory length:', 1000)
# ('episode:', 980, '  score:', 200.0, ' q_value:', array([19.20432792]), '  memory length:', 1000)
# ('episode:', 981, '  score:', 200.0, ' q_value:', array([19.60064387]), '  memory length:', 1000)
# ('episode:', 982, '  score:', 200.0, ' q_value:', array([19.48195099]), '  memory length:', 1000)
# ('episode:', 983, '  score:', 200.0, ' q_value:', array([19.40233132]), '  memory length:', 1000)
# ('episode:', 984, '  score:', 200.0, ' q_value:', array([19.46283687]), '  memory length:', 1000)
# ('episode:', 985, '  score:', 200.0, ' q_value:', array([19.24521874]), '  memory length:', 1000)
# ('episode:', 986, '  score:', 200.0, ' q_value:', array([19.19967896]), '  memory length:', 1000)
# ('episode:', 987, '  score:', 173.0, ' q_value:', array([19.21270711]), '  memory length:', 1000)
# ('episode:', 988, '  score:', 138.0, ' q_value:', array([19.20724849]), '  memory length:', 1000)
# ('episode:', 989, '  score:', 162.0, ' q_value:', array([19.27229246]), '  memory length:', 1000)
# ('episode:', 990, '  score:', 108.0, ' q_value:', array([19.2952258]), '  memory length:', 1000)
# ('episode:', 991, '  score:', 105.0, ' q_value:', array([19.50511071]), '  memory length:', 1000)
# ('episode:', 992, '  score:', 135.0, ' q_value:', array([19.48046346]), '  memory length:', 1000)
# ('episode:', 993, '  score:', 139.0, ' q_value:', array([19.61978331]), '  memory length:', 1000)
# ('episode:', 994, '  score:', 135.0, ' q_value:', array([19.51721363]), '  memory length:', 1000)
# ('episode:', 995, '  score:', 132.0, ' q_value:', array([19.58966514]), '  memory length:', 1000)
# ('episode:', 996, '  score:', 156.0, ' q_value:', array([19.56443799]), '  memory length:', 1000)
# ('episode:', 997, '  score:', 193.0, ' q_value:', array([19.5923392]), '  memory length:', 1000)
# ('episode:', 998, '  score:', 188.0, ' q_value:', array([19.62265703]), '  memory length:', 1000)
# ('episode:', 999, '  score:', 175.0, ' q_value:', array([19.57900221]), '  memory length:', 1000)
